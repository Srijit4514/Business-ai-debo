# %% [markdown]
# # Business Analytics Pipeline Research
# This notebook is used for testing and validating each stage of the business analytics pipeline.
#
# ### 1. Data Ingestion
# ### 2. Data Validation
# ### 3. Data Transformation
# ### 4. Model/Analytics Generation

# %%
import os
os.chdir("../")
print(os.getcwd())

# %%
from business_analytics.utils import read_yaml, create_directories
from business_analytics.constants import *
from pathlib import Path

config = read_yaml(CONFIG_FILE_PATH)
print(config.artifacts_root)
